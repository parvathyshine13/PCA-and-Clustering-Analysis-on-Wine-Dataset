# %% [markdown]
# ### Exploratory Data Analysis (EDA):

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df =pd.read_csv(r"C:\Users\Parvathy Shine\Desktop\Assignments\9. PCA\PCA\wine.csv")
df
# Out:
#      Type  Alcohol  Malic   Ash  Alcalinity  Magnesium  Phenols  Flavanoids  \
# 0       1    14.23   1.71  2.43        15.6        127     2.80        3.06
# 1       1    13.20   1.78  2.14        11.2        100     2.65        2.76
# 2       1    13.16   2.36  2.67        18.6        101     2.80        3.24
# 3       1    14.37   1.95  2.50        16.8        113     3.85        3.49
# 4       1    13.24   2.59  2.87        21.0        118     2.80        2.69
# ..    ...      ...    ...   ...         ...        ...      ...         ...
# 173     3    13.71   5.65  2.45        20.5         95     1.68        0.61
# 174     3    13.40   3.91  2.48        23.0        102     1.80        0.75
# 175     3    13.27   4.28  2.26        20.0        120     1.59        0.69
# 176     3    13.17   2.59  2.37        20.0        120     1.65        0.68
# 177     3    14.13   4.10  2.74        24.5         96     2.05        0.76
#
# ...

# %%
# EDA:

df.info() # No missing values and all are numerical variables
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Type             178 non-null    int64
#  1   Alcohol          178 non-null    float64
#  2   Malic            178 non-null    float64
#  3   Ash              178 non-null    float64
#  4   Alcalinity       178 non-null    float64
#  5   Magnesium        178 non-null    int64
#  6   Phenols          178 non-null    float64
#  7   Flavanoids       178 non-null    float64
#  8   Nonflavanoids    178 non-null    float64
#  9   Proanthocyanins  178 non-null    float64
#  10  Color            178 non-null    float64
#  11  Hue              178 non-null    float64
#  12  Dilution         178 non-null    float64
#  13  Proline          178 non-null    int64
# dtypes: float64(11), int64(3)
# memory usage: 19.6 KB

# %%
df.describe()
# Out:
#              Type     Alcohol       Malic         Ash  Alcalinity   Magnesium  \
# count  178.000000  178.000000  178.000000  178.000000  178.000000  178.000000
# mean     1.938202   13.000618    2.336348    2.366517   19.494944   99.741573
# std      0.775035    0.811827    1.117146    0.274344    3.339564   14.282484
# min      1.000000   11.030000    0.740000    1.360000   10.600000   70.000000
# 25%      1.000000   12.362500    1.602500    2.210000   17.200000   88.000000
# 50%      2.000000   13.050000    1.865000    2.360000   19.500000   98.000000
# 75%      3.000000   13.677500    3.082500    2.557500   21.500000  107.000000
# max      3.000000   14.830000    5.800000    3.230000   30.000000  162.000000
#
#           Phenols  Flavanoids  Nonflavanoids  Proanthocyanins       Color  \
# count  178.000000  178.000000     178.000000       178.000000  178.000000
# mean     2.295112    2.029270       0.361854         1.590899    5.058090
# ...

# %%
#Histogram

cols = df.select_dtypes(include=['int64','float64']).columns # Selecting all the coloumns
for col in cols:
    df[col].hist(bins=30,color='lightblue',edgecolor='purple')
    plt.title(f'Histogram of {col}')
    plt.show()

# Inference: 
# 1. Malic ,flavanoids ,Proline- right-skewed
# 2. ash, alcalinity,alcohol - symmetric distribution

# %%
# Boxplot :

for col in cols:
    sns.boxplot(df[col],color='purple')
    plt.title(f'Boxplot of {col}')
    plt.show()

# Inference:
# 1. Flavanoids, Magnesium , Proline- large IQR

# %%
#Density Plots:

for col in cols:
    sns.kdeplot(df[col],color='orange')
    plt.title(f'Density Plot of {col}')
    plt.show()

#Inference:
# 1. Malic, Proline, Flavanoids - skewed curves
# 2. Ash, Alcohol - symmetric curve
# Out:
# C:\Users\Parvathy Shine\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Parvathy Shine\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Parvathy Shine\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
# Heatmap of the correlation matrix

c=df.corr()
plt.figure(figsize=(12,8))
sns.heatmap(c, annot=True, cmap='RdBu', fmt='.2f')
plt.title('Correlation Matrix Heatmap')
plt.show()

# %% [markdown]
# #### Dimensionality Reduction with PCA:

# %%
# Standardizing the Features :

from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
df_scaled = sc.fit_transform(df[cols])

# %%
# Fiting PCA on scaled data

from sklearn.decomposition import PCA
pca= PCA()
pca.fit(df_scaled)
# Out:
# PCA()

# %%
# Screeplot to determine optimal number of components (hom much variance in each PC)

# Explained variance ratio ( proportion of total variance by each principal component tv+tv=1) 
#                          Full of arrays
ex_v = pca.explained_variance_ratio_

#Plotting the Screeplot:

plt.plot(range(1, len(ex_v) + 1), pca.explained_variance_ratio_, marker='o')
#        range(1, len(...) + 1) = starting from 1 to PCs

plt.xlabel('Principal Component')
plt.ylabel('Explained Variance Ratio')
plt.title('Scree Plot')
plt.show()

# %%
# Cumulative Explained Variance [variance*(pc1,pc1+pc2,pc1+pc2+pc3....)]


cu_v = np.cumsum(ex_v)  # sum variance progressively

plt.plot(range(1, len(cu_v) + 1), cu_v, marker='o')
plt.xlabel('Number of Principal Components')
plt.ylabel('Cumulative Explained Variance')
plt.title('Cumulative Explained Variance Plot')
plt.axhline(y=0.95, color='g', linestyle='--', label='95% Explained Variance') #To see the point reaches the 95% Threshold
plt.legend()
plt.grid(True)
plt.show()

# Find the index where cumulative variance >= 0.95
hit_at_95 = np.argmax(cu_v >= 0.95) + 1 # argmax - find the first principal component that crosses the 95% variance threshold.
print(f"Number of components to reach 95% variance: {hit_at_95}")
# Out:
# Number of components to reach 95% variance: 10

# %%
#Transform scaled data to Principal Components.

pca = PCA(n_components= 10)  # From the figure
df_pca = pca.fit_transform(df_scaled)
print("Transformed dataset shape:", df_pca.shape)
# Out:
# Transformed dataset shape: (178, 10)

# %% [markdown]
# ### Clustering with Original Data:

# %%
#Clustering with Original Plot

# Applying KMeans (OG):
from sklearn.cluster import KMeans
kmeans_og = KMeans(n_clusters=3, random_state=42) 
kmeans_og.fit(df_scaled)
labels_og = kmeans.labels_ # Add the cluster labels to the data

# Visualising the clusters
plt.figure(figsize=(8, 6))
plt.scatter(df_scaled[:, 0], df_scaled[:, 1], c=labels_og, cmap='plasma', s=50)
plt.title("K-Means Clustering (Original Data)")
plt.xlabel("PCA Component 1")
plt.ylabel("PCA Component 2")
plt.colorbar(label='Cluster')
plt.show()
# Out:
# C:\Users\Parvathy Shine\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\Parvathy Shine\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
#Silhouette Score: Measures how well each point fits in its cluster (higher is better, range: -1 to 1)

from sklearn.metrics import silhouette_score
s_score = silhouette_score(df_scaled, labels_og)
print(f"Silhouette Score: {s_score:.3f}")

# Davies–Bouldin Index: Lower score means better clustering

from sklearn.metrics import davies_bouldin_score
db_index = davies_bouldin_score(df_scaled, labels_og)
print(f"Davies–Bouldin Index: {db_index:.3f}")
# Out:
# Silhouette Score: 0.308
# Davies–Bouldin Index: 1.316

# %% [markdown]
# #### Clustering with PCA Data:

# %%
#Clustering with PCA Data:

# Applying KMeans (PCA):
from sklearn.cluster import KMeans
kmeans_pca = KMeans(n_clusters=3, random_state=42) 
kmeans_pca.fit(df_pca)
labels_pca = kmeans.labels_ # Add the cluster labels to the data

# Visualising the clusters
plt.figure(figsize=(8, 6))
plt.scatter(df_pca[:, 0], df_pca[:, 1], c=labels_pca, cmap='plasma', s=50)
plt.title("K-Means Clustering (PCA data)")
plt.xlabel("PCA Component 1")
plt.ylabel("PCA Component 2")
plt.colorbar(label='Cluster')
plt.show()
# Out:
# C:\Users\Parvathy Shine\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\Parvathy Shine\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
#Silhouette Score:       Higher Silhouette Score= Clusters are more distinct and well-separated.

from sklearn.metrics import silhouette_score
s_score_pca = silhouette_score(df_pca, labels_pca)
print(f"Silhouette Score: {s_score_pca:.3f}")

# Davies–Bouldin Index:   Lower Davies–Bouldin Index = Clusters are less similar to each other.

from sklearn.metrics import davies_bouldin_score
db_index_pca = davies_bouldin_score(df_pca, labels_pca)
print(f"Davies–Bouldin Index: {db_index_pca:.3f}")
# Out:
# Silhouette Score: 0.324
# Davies–Bouldin Index: 1.258

# %% [markdown]
# Inference from comparing both :
#
# <br>Silhouette Score (Higher is Better) - Ranges from -1 to 1
# <br>Davies–Bouldin Index (Lower is Better)
#
# <br>Comparing both the scores - PCA has better data for clustering : Clusters are more distinct and less similar to each other.

# %% [markdown]
# ### Comparison and Analysis:

# %% [markdown]
# ##### Similarities:
#
# 1. Overall cluster approach and number of clusters remained the same.
# 2. Cluster structures are formed in both.
#
# ##### Differnces:
#
# 1. The cluster quality improved with PCA due to less noise and redundant features , cleaner separation btw clusters in fewer dimensions.
# 2. Visualisations after PCA are easier to interpret.
#
# ##### Impact of Dimensionality Reduction (PCA):
#
# 1. Improved clustering performance and Simplified visualization
# 2. Noise reduction: PCA removes irrelevant variance, focusing on what really matters in the data.
# 3. Faster computation: Fewer dimensions mean quicker clustering.
# 4. It loses direct Interpretablity of features.
#
# ##### Trade -Offs - PCA vs Original Data
#
# 1. Accuracy : PCA is better due to noise reduction.
# 2. Interpretablity : PCA is better to visualise.
# 3. Feature Meaning : Original data are interpretable but PCA components are abstract.
# 4. Performance : Faster clustering with PCA and reduces computational cost too.
# 5. Overfitting Risk : PCA has reduced overfitting.
#
# ###### If every feature matters, use original data . for better cluster quality and performance, use PCA.

# %% [markdown]
# ### Conclusion and Insights
#
# 1.Summarize the key findings and insights from the assignment.
# <br>2.Discuss the practical implications of using PCA and clustering in data analysis.
# <br>3.Provide recommendations for when to use each technique based on the analysis conducted.

# %% [markdown]
# #### Key findings:
#
# 1. Clustering on PCA-transformed data outperformed clustering on the original dataset.
# 2. PCA helped reduce dimensionality while preserving 95% of the original variance, making the data easier to handle and visualize.
#
# #### Practical Implications:
#
# 1. PCA (Principal Component Analysis) is a powerful tool to simplify complex datasets by removing noise and redundancy, enhancing clustering quality and speed.
# 2. Clustering algorithms like KMeans benefit from cleaner data, resulting in more meaningful groupings when PCA is applied beforehand.
# EG : Used both in Customer segmentation, Anomaly Detection and Pattern Recognition.
#
# #### Recommendations:
#
# Use PCA when:
# 1. Large datasets with many features.
# 2. when visualisation is needed.
# 3. when performance and speed is important
#
# Use Original data:
# 1. when each feature intrepretablity is critical.
